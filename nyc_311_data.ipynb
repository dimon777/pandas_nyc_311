# %%
import pandas as pd
import requests as rq

# %%
#nyc complains data: 
complains_url="https://data.cityofnewyork.us/api/views/erm2-nwe9/rows.csv"
#complains_url="data/2017_small.csv"
# population by zip: 
pop_byzip_url = "https://data.cityofnewyork.us/resource/rreq-n6zk.csv"
#pop_byzip_url = "data/pop_by_zip.csv"

pop_byborough_url = "https://data.cityofnewyork.us/api/views/h2bk-zmw6/rows.csv?accessType=DOWNLOAD"
chunksize = 100000
year=2017

# %% [markdown]
# #### for some reason pandas ignores nrows() when reading from URL so we use bash magic to expolore schema

# %%
# %%bash -s "$complains_url" "$pop_byzip_url" "$pop_byborough_url"
# echo "++++++++++++++++++++++++++++++ COMPLAINS ++++++++++++++++++++++++++++++++"
# wget -qO- $1 | head -2
#
# echo "++++++++++++++++++++++++ POPULATION BY ZIP CODES ++++++++++++++++++++++++"
# wget -qO- $2 | head -2
#
# echo "+++++++++++++++++++++++++ POPULATION BY BOROUGH +++++++++++++++++++++++++"
# wget -qO- $3 | head -2
# Out:
# ++++++++++++++++++++++++++++++ COMPLAINS ++++++++++++++++++++++++++++++++
# Unique Key,Created Date,Closed Date,Agency,Agency Name,Complaint Type,Descriptor,Location Type,Incident Zip,Incident Address,Street Name,Cross Street 1,Cross Street 2,Intersection Street 1,Intersection Street 2,Address Type,City,Landmark,Facility Type,Status,Due Date,Resolution Description,Resolution Action Updated Date,Community Board,BBL,Borough,X Coordinate (State Plane),Y Coordinate (State Plane),Open Data Channel Type,Park Facility Name,Park Borough,Vehicle Type,Taxi Company Borough,Taxi Pick Up Location,Bridge Highway Name,Bridge Highway Direction,Road Ramp,Bridge Highway Segment,Latitude,Longitude,Location
# 31317560,08/15/2015 11:42:16 PM,08/16/2015 01:12:47 AM,NYPD,New York City Police Department,Noise - Commercial,Loud Music/Party,Club/Bar/Restaurant,10013,134 READE STREET,READE STREET,HUDSON STREET,GREENWICH STREET,,,ADDRESS,NEW YORK,,Precinct,Closed,08/16/2015 07:42:16 AM,The Police Department responded to the complaint and determined that police action was not necessary.,08/16/2015 01:12:47 AM,01 MANHATTAN,1001410002,MANHATTAN,981575,200280,PHONE,Unspecified,MANHATTAN,,,,,,,,40.71639866613832,-74.0096496327318,"(40.71639866613832, -74.0096496327318)"
# ++++++++++++++++++++++++ POPULATION BY ZIP CODES ++++++++++++++++++++++++
# "count_american_indian","count_asian_non_hispanic","count_black_non_hispanic","count_citizen_status_total","count_citizen_status_unknown","count_ethnicity_total","count_ethnicity_unknown","count_female","count_gender_total","count_gender_unknown","count_hispanic_latino","count_male","count_nreceives_public_assistance","count_other_citizen_status","count_other_ethnicity","count_pacific_islander","count_participants","count_permanent_resident_alien","count_public_assistance_total","count_public_assistance_unknown","count_receives_public_assistance","count_us_citizen","count_white_non_hispanic","jurisdiction_name","percent_american_indian","percent_asian_non_hispanic","percent_black_non_hispanic","percent_citizen_status_total","percent_citizen_status_unknown","percent_ethnicity_total","percent_ethnicity_unknown","percent_female","percent_gender_total","percent_gender_unknown","percent_hispanic_latino","percent_male","percent_nreceives_public_assistance","percent_other_citizen_status","percent_other_ethnicity","percent_pacific_islander","percent_permanent_resident_alien","percent_public_assistance_total","percent_public_assistance_unknown","percent_receives_public_assistance","percent_us_citizen","percent_white_non_hispanic"
# "0","3","21","44","0","44","0","22","44","0","16","22","24","0","3","0","44","2","44","0","20","42","1","10001","0","0.07","0.48","100","0","100","0","0.5","100","0","0.36","0.5","0.55","0","0.07","0","0.05","100","0","0.45","0.95","0.02"
# +++++++++++++++++++++++++ POPULATION BY BOROUGH +++++++++++++++++++++++++
# Borough,Population
# Brooklyn,4970026

# %% [markdown]
# ### Data loading, transforming & exploration

# %%
# Filter by year of interest: 2017 and remove 'Borough' == "Unspecified"
# We read in chunks to keep memory consumption controlled iterator=True, 
iter_df=pd.read_csv(complains_url, skipinitialspace=True, usecols=['Unique Key','Created Date','Borough','Zip','City','Complaint Type'], chunksize=chunksize)
#df = pd.concat([chunk[(pd.to_datetime(chunk['Created Date']).dt.year == year) & (chunk['Borough'] != "Unspecified")] for chunk in iter_df])
chunks = []
for chunk in iter_df:
    chunks.append(chunk[(pd.to_datetime(chunk['Created Date']).dt.year == year) & (chunk['Borough'] != "Unspecified")])

df = pd.concat(chunks, axis=0, ignore_index=True)

# %%
df.head(n=5)
# Out:
#    Unique Key         Created Date    Borough      Zip      City  \
# 1    35139948  2017-01-01 00:00:59      BRONX  10467.0     BRONX
# 2    35140478  2017-01-01 00:01:43     QUEENS  11368.0    CORONA
# 3    35138317  2017-01-01 00:02:54   BROOKLYN  11209.0  BROOKLYN
# 4    35139300  2017-01-01 00:03:41  MANHATTAN  10040.0  NEW YORK
# 5    35143952  2017-01-01 00:03:42      BRONX  10470.0     BRONX
#
#         Complaint Type
# 1       HEAT/HOT WATER
# 2     Blocked Driveway
# 3  Noise - Residential
# 4  Noise - Residential
# 5       HEAT/HOT WATER

# %%
df.to_csv("data/nyc_311_2017.csv", index=False)

# %%
df.dtypes
# Out:
# Unique Key          int64
# Created Date       object
# Borough            object
# Zip               float64
# City               object
# Complaint Type     object
# dtype: object

# %%
df.describe(include = 'all')
# Out:
#           Unique Key         Created Date   Borough           Zip      City  \
# count   9.990000e+02                  999       999    995.000000       995
# unique           NaN                  942         6           NaN        40
# top              NaN  2017-01-01 00:56:16  BROOKLYN           NaN  BROOKLYN
# freq             NaN                    8       316           NaN       316
# mean    3.514285e+07                  NaN       NaN  10797.300503       NaN
# std     3.365970e+03                  NaN       NaN    552.737019       NaN
# min     3.513692e+07                  NaN       NaN  10001.000000       NaN
# 25%     3.514006e+07                  NaN       NaN  10306.000000       NaN
# 50%     3.514302e+07                  NaN       NaN  11203.000000       NaN
# 75%     3.514578e+07                  NaN       NaN  11233.000000       NaN
# max     3.514822e+07                  NaN       NaN  11694.000000       NaN
#
#              Complaint Type
# count                   999
# unique                   44
# top     Noise - Residential
# freq                    561
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 1 to 999
# Data columns (total 6 columns):
# Unique Key        999 non-null int64
# Created Date      999 non-null object
# Borough           999 non-null object
# Zip               995 non-null float64
# City              995 non-null object
# Complaint Type    999 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 54.6+ KB

# %%
df_borough = df[['Borough']].drop_duplicates()
df_borough
# Out:
#            Borough
# 1            BRONX
# 2           QUEENS
# 3         BROOKLYN
# 4        MANHATTAN
# 9    STATEN ISLAND
# 132    Unspecified

# %%
df.groupby(['Borough'])['Borough'].count().reset_index(name='cnt').sort_values(by='cnt', ascending=False)
# Out:
#          Borough  cnt
# 1       BROOKLYN  316
# 2      MANHATTAN  239
# 3         QUEENS  218
# 0          BRONX  197
# 4  STATEN ISLAND   26
# 5    Unspecified    3

# %%
df_compl_type = df[['Complaint Type']].drop_duplicates()
df_compl_type
# Out:
#                     Complaint Type
# 1                   HEAT/HOT WATER
# 2                 Blocked Driveway
# 3              Noise - Residential
# 6         Traffic Signal Condition
# 12              Noise - Commercial
# 22         Noise - Street/Sidewalk
# 39                 Illegal Parking
# 40                   Drug Activity
# 51      Homeless Person Assistance
# 55          Street Light Condition
# 60                Street Condition
# 77               Electronics Waste
# 82              Noise - Helicopter
# 87                 Noise - Vehicle
# 96              Sidewalk Condition
# 109           Sanitation Condition
# 118                   Building/Use
# 129                          Noise
# 133     For Hire Vehicle Complaint
# 155                       Drinking
# 215                     WATER LEAK
# 216                  PAINT/PLASTER
# 218           UNSANITARY CONDITION
# 219                    DOOR/WINDOW
# 220                         SAFETY
# 240             Indoor Air Quality
# 262                       Elevator
# 272               Derelict Vehicle
# 303              Derelict Vehicles
# 314                    Taxi Report
# 316                   Water System
# 329                        Smoking
# 342             Consumer Complaint
# 365                 Taxi Complaint
# 430     Illegal Animal Kept as Pet
# 460                   Animal Abuse
# 501         Street Sign - Dangling
# 608       Noise - House of Worship
# 615                       ELECTRIC
# 659             Food Establishment
# 660                      APPLIANCE
# 661                        GENERAL
# 662                FLOORING/STAIRS
# 679  General Construction/Plumbing

# %%
# Borough == Unspecified is less then 0.5% of all records so we are going to drop those records from the DataFrame
# This also can be done at a loading time (see above)
df = df[df['Borough'].map(lambda x: str(x) != "Unspecified")]
df.count()
# Out:
# Unique Key        996
# Created Date      996
# Borough           996
# Zip               995
# City              995
# Complaint Type    996
# dtype: int64

# %%
df.groupby(['Borough'])['Borough'].count().reset_index(name='cnt').sort_values(by='cnt', ascending=False)
# Out:
#          Borough  cnt
# 1       BROOKLYN  316
# 2      MANHATTAN  239
# 3         QUEENS  218
# 0          BRONX  197
# 4  STATEN ISLAND   26

# %%
# There are few complains where City or/and Zip is Nan:
city_null = df['City'].isnull()
zip_null = df['Zip'].isnull()

# Select these cases:
df[zip_null | city_null]
# Out:
#      Unique Key         Created Date    Borough  Zip City  \
# 110    35143285  2017-01-01 00:34:00  MANHATTAN  NaN  NaN
#
#              Complaint Type
# 110  Street Light Condition

# %%
df = df[df['Zip'].notnull() | df['City'].notnull()]
df.count()
# Out:
# Unique Key        995
# Created Date      995
# Borough           995
# Zip               995
# City              995
# Complaint Type    995
# dtype: int64

# %% [markdown]
# ### Assessment part

# %% [markdown]
# #### 1. Consider only the 10 most common overall complaint types. For each borough, how many of each of those 10 types were there in 2017?

# %%
# First top 10 complains types:
top10_complains = df.groupby(['Complaint Type'])['Complaint Type'].count().reset_index(name='cnt').sort_values(by='cnt', ascending=False).head(n=10)
top10_complains
# Out:
#              Complaint Type  cnt
# 27      Noise - Residential  559
# 24       Noise - Commercial  103
# 2          Blocked Driveway   65
# 18           HEAT/HOT WATER   59
# 28  Noise - Street/Sidewalk   54
# 21          Illegal Parking   40
# 35         Street Condition   19
# 29          Noise - Vehicle   10
# 38           Taxi Complaint    8
# 41     UNSANITARY CONDITION    6

# %%
all_merged_with_top10 = pd.merge(top10_complains, df, on='Complaint Type')

# %%
# For each borough, how many of each of those 10 types were there in 2017?
top10_borough_complains = all_merged_with_top10.groupby(['Borough','Complaint Type'])['Complaint Type'].count().reset_index(name='cnt').sort_values(by=['Borough','cnt'], ascending=[True, False])
top10_borough_complains
# Out:
#           Borough           Complaint Type  cnt
# 4           BRONX      Noise - Residential  129
# 1           BRONX           HEAT/HOT WATER   21
# 0           BRONX         Blocked Driveway   17
# 2           BRONX          Illegal Parking    7
# 3           BRONX       Noise - Commercial    2
# 5           BRONX  Noise - Street/Sidewalk    2
# 6           BRONX          Noise - Vehicle    2
# 7           BRONX     UNSANITARY CONDITION    1
# 12       BROOKLYN      Noise - Residential  152
# 11       BROOKLYN       Noise - Commercial   53
# 9        BROOKLYN           HEAT/HOT WATER   23
# 13       BROOKLYN  Noise - Street/Sidewalk   22
# 8        BROOKLYN         Blocked Driveway   17
# 10       BROOKLYN          Illegal Parking   14
# 15       BROOKLYN         Street Condition   10
# 17       BROOKLYN     UNSANITARY CONDITION    4
# 14       BROOKLYN          Noise - Vehicle    3
# 16       BROOKLYN           Taxi Complaint    2
# 21      MANHATTAN      Noise - Residential  134
# 20      MANHATTAN       Noise - Commercial   38
# 22      MANHATTAN  Noise - Street/Sidewalk   19
# 18      MANHATTAN           HEAT/HOT WATER   10
# 24      MANHATTAN         Street Condition    8
# 19      MANHATTAN          Illegal Parking    7
# 25      MANHATTAN           Taxi Complaint    6
# 23      MANHATTAN          Noise - Vehicle    1
# 30         QUEENS      Noise - Residential  131
# 26         QUEENS         Blocked Driveway   28
# 28         QUEENS          Illegal Parking   11
# 31         QUEENS  Noise - Street/Sidewalk   10
# 29         QUEENS       Noise - Commercial    9
# 27         QUEENS           HEAT/HOT WATER    5
# 32         QUEENS          Noise - Vehicle    4
# 33         QUEENS         Street Condition    1
# 34         QUEENS     UNSANITARY CONDITION    1
# 38  STATEN ISLAND      Noise - Residential   13
# 35  STATEN ISLAND         Blocked Driveway    3
# 36  STATEN ISLAND          Illegal Parking    1
# 37  STATEN ISLAND       Noise - Commercial    1
# 39  STATEN ISLAND  Noise - Street/Sidewalk    1

# %%
# top 10 complains by each borough (this contains exaclt 10 rows per borough):
top10_complains_by_borough = df.groupby(['Borough','Complaint Type'])['Complaint Type'].count().groupby(level='Borough').nlargest(10).reset_index(level=0, drop=True)
top10_complains_by_borough
# Out:
# Borough        Complaint Type
# BRONX          Noise - Residential           129
#                HEAT/HOT WATER                 21
#                Blocked Driveway               17
#                Illegal Parking                 7
#                Illegal Animal Kept as Pet      4
#                Drug Activity                   2
#                GENERAL                         2
#                Noise - Commercial              2
#                Noise - Street/Sidewalk         2
#                Noise - Vehicle                 2
# BROOKLYN       Noise - Residential           152
#                Noise - Commercial             53
#                HEAT/HOT WATER                 23
#                Noise - Street/Sidewalk        22
#                Blocked Driveway               17
#                Illegal Parking                14
#                Street Condition               10
#                UNSANITARY CONDITION            4
#                Noise - Vehicle                 3
#                Traffic Signal Condition        3
# MANHATTAN      Noise - Residential           134
#                Noise - Commercial             38
#                Noise - Street/Sidewalk        19
#                HEAT/HOT WATER                 10
#                Street Condition                8
#                Illegal Parking                 7
#                Taxi Complaint                  6
#                Noise                           3
#                Taxi Report                     3
#                Street Light Condition          2
# QUEENS         Noise - Residential           131
#                Blocked Driveway               28
#                Illegal Parking                11
#                Noise - Street/Sidewalk        10
#                Noise - Commercial              9
#                HEAT/HOT WATER                  5
#                Noise - Vehicle                 4
#                DOOR/WINDOW                     3
#                Building/Use                    2
#                Derelict Vehicle                2
# STATEN ISLAND  Noise - Residential            13
#                Blocked Driveway                3
#                Electronics Waste               2
#                Building/Use                    1
#                Derelict Vehicle                1
#                Derelict Vehicles               1
#                For Hire Vehicle Complaint      1
#                Illegal Parking                 1
#                Noise - Commercial              1
#                Noise - Street/Sidewalk         1
# Name: Complaint Type, dtype: int64

# %% [markdown]
# #### 2. Consider only the 10 most common overall complaint types. For the 10 most populous zip codes, how many of each of those 10 types were there in 2017?

# %%
#1. Find top 10 mst populous zip codes
top10_zip_pop = pd.read_csv(pop_byzip_url, skipinitialspace=True, usecols=['jurisdiction_name','count_participants']).sort_values(by=['count_participants'], ascending=[False]).head(10)
top10_zip_pop
# Out:
#      count_participants  jurisdiction_name
# 232                 272              12789
# 218                 252              12734
# 130                 248              11230
# 228                 242              12779
# 120                 214              11219
# 229                 201              12783
# 222                 134              12754
# 210                 124              12428
# 119                 111              11218
# 124                 109              11223

# %%
t_df = pd.merge(top10_zip_pop, df, left_on="jurisdiction_name", right_on='Zip')

# %%
top10_complains_by_zip = t_df.groupby(['Zip','Complaint Type'])['Complaint Type'].count().groupby(level='Zip').nlargest().reset_index(level=0, drop=True)
top10_complains_by_zip
# Out:
# Zip      Complaint Type
# 11218.0  Noise - Residential        2
#          Taxi Complaint             1
# 11219.0  Noise - Residential        3
#          Noise - Commercial         1
# 11223.0  Noise - Residential        5
#          Noise - Commercial         1
#          Noise - Street/Sidewalk    1
#          Smoking                    1
# 11230.0  Noise - Residential        2
# Name: Complaint Type, dtype: int64

# %% [markdown]
# #### 3. Considering all complaint types. Which boroughs are the biggest "complainers" relative to the size of the population in 2017 Meaning, calculate a complaint-index that adjusts for population of the borough

# %%
borough_popul = pd.read_csv(pop_byborough_url, skipinitialspace=True).apply(lambda x: x.astype(str).str.upper())
borough_popul
# Out:
#          Borough Population
# 0       BROOKLYN    4970026
# 1      MANHATTAN    3123068
# 2          BRONX    2717758
# 3         QUEENS    4460101
# 4  STATEN ISLAND     912458

# %%
borough_compl = df.groupby(['Borough'])['Borough'].count().reset_index(name='complains')
borough_compl
# Out:
#          Borough  complains
# 0          BRONX        197
# 1       BROOKLYN        316
# 2      MANHATTAN        238
# 3         QUEENS        218
# 4  STATEN ISLAND         26

# %%
borough_compl_per_popul_unit = pd.merge(borough_compl, borough_popul, on="Borough")
borough_compl_per_popul_unit['compl_per_1m_popul'] = 1000000*borough_compl_per_popul_unit['complains']/borough_compl_per_popul_unit['Population']
borough_compl_per_popul_unit = borough_compl_per_popul_unit.sort_values(by=['compl_per_1m_popul'], ascending=[False])
borough_compl_per_popul_unit
# Out:
#          Borough  complains  Population  compl_per_1m_popul
# 2      MANHATTAN        238     3123068           76.207114
# 0          BRONX        197     2717758           72.486218
# 1       BROOKLYN        316     4970026           63.581156
# 3         QUEENS        218     4460101           48.877817
# 4  STATEN ISLAND         26      912458           28.494462
